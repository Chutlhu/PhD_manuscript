# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

sns.set()

# %%
df = df = pd.read_csv("../../assets/lantern/gcc_mlp_cnn.csv")

# %%
df
# Out:
#           When  Approach signal  SNR   TDOA  iTDOA  TODE1
# 0   ICASSP2018  GCC-PHAT   wn+n   10  0.680      -      -
# 1   ICASSP2018  GCC-PHAT   sp+n   10  1.380      -      -
# 2      Current     MLP V   wn+n   10  0.680   0.69   0.89
# 3      Current     MLP V   sp+n   10  0.990   0.98   1.48
# 4      Current     CNN V   wn+n    0  0.137  0.145  0.209
# 5      Current     CNN V   sp+n    0  0.137  0.145  0.209
# 6      Current     CNN V   wn+n   10  0.192  0.196  0.284
# 7      Current     CNN V   sp+n   10  0.192  0.196  0.284
# 8      Current     CNN V   wn+n   20  0.148  0.151  0.222
# 9      Current     CNN V   sp+n   20  0.148  0.151  0.222
# 10     Current    CNN VN   wn+n    0  0.103  0.111  0.248
# 11     Current    CNN VN   sp+n    0  0.103  0.111  0.248
# 12     Current    CNN VN   wn+n   10  0.102   0.11   0.28
# 13     Current    CNN VN   sp+n   10  0.102   0.11   0.28
# 14     Current    CNN VN   wn+n   20  0.137  0.108  0.222
# ...
